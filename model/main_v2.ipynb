# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib
from Constants import *

# %%
train_dataset = keras.preprocessing.image_dataset_from_directory(
    TRAIN_PATH,
    shuffle = True,
    image_size = (image_size, image_size),
    batch_size = BATCH_SIZE
)
# Out:
# Found 5712 files belonging to 4 classes.

# %%
test_dataset = keras.preprocessing.image_dataset_from_directory(
    VALIDATION_PATH,
    shuffle = True,
    image_size = (image_size, image_size),
    batch_size = BATCH_SIZE
)
# Out:
# Found 1311 files belonging to 4 classes.

# %%
class_names = test_dataset.class_names
print(class_names)
num_classes = len(class_names)
print(num_classes)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']
# 4

# %%
plt.figure(figsize = (10, 8))
for image_batch, label_batch in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %%
#train_size = int(0.85 * len(train_dataset))
#val_size = int(0.15 * len(train_dataset))
test_size = int(1 * len(test_dataset))

# %%
#train_set = train_dataset.take(train_size)
#val_set = train_dataset.skip(train_size)
test_set = test_dataset.take(test_size)

# %%
print(len(train_set),'\n',len(test_set),'\n',len(val_set))
# Out:
# 303
#  82
#  54

# %%
AUTOTUNE = tf.data.AUTOTUNE

# %%
resize_and_rescale = keras.Sequential([
    layers.experimental.preprocessing.Resizing(image_size, image_size),
    layers.experimental.preprocessing.Rescaling(1.0 / 255)
])

# %%
augmented_data = keras.Sequential([
    layers.RandomFlip("horizontal",
                      input_shape = (image_size, image_size,
                                     3)),
    layers.RandomRotation(0.25),
    layers.RandomZoom(0.25),
    layers.RandomFlip("horizontal_and_vertical")
])

# %%
plt.figure(figsize = (8, 6))
for images, label in train_set.take(1):
    for i in range(9):
        augmented_images = augmented_data(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.title(class_names[label[i]])
        plt.imshow(augmented_images[i].numpy().astype("uint8"))
        plt.axis("off")

# %%
#train_set = train_set.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)
#val_set = val_set.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)
test_set = test_set.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)

# %%
input_shape = (BATCH_SIZE, image_size, image_size, 3)

model = keras.Sequential([
    resize_and_rescale,
    augmented_data,
    layers.Conv2D(64, (3, 3), activation = 'relu', input_shape = input_shape),
    #layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    layers.Conv2D(32, (3, 3), activation = 'relu'),
    #layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),
    layers.Conv2D(64, (3, 3), activation = 'relu'),
    #layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    layers.Conv2D(32, (3, 3), activation = 'relu'),
    #layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),
    layers.Conv2D(64, (3, 3), activation = 'relu'),
    #layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(64, activation = 'relu'),
    layers.Dropout(0.25),
    layers.Dense(num_classes, activation = 'softmax'),    
])

model.build(input_shape = input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (16, 224, 224, 3)         0
#
#  sequential_1 (Sequential)   (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (16, 222, 222, 64)        1792
#
#  max_pooling2d (MaxPooling2  (16, 111, 111, 64)        0
#  D)
#
#  dropout (Dropout)           (16, 111, 111, 64)        0
#
#  conv2d_1 (Conv2D)           (16, 109, 109, 32)        18464
#
#  max_pooling2d_1 (MaxPoolin  (16, 54, 54, 32)          0
#  g2D)
#
#  dropout_1 (Dropout)         (16, 54, 54, 32)          0
#
#  conv2d_2 (Conv2D)           (16, 52, 52, 64)          18496
#
#  max_pooling2d_2 (MaxPoolin  (16, 26, 26, 64)          0
#  g2D)
#
#  dropout_2 (Dropout)         (16, 26, 26, 64)          0
#
#  conv2d_3 (Conv2D)           (16, 24, 24, 32)          18464
#
#  max_pooling2d_3 (MaxPoolin  (16, 12, 12, 32)          0
#  g2D)
#
#  dropout_3 (Dropout)         (16, 12, 12, 32)          0
#
#  conv2d_4 (Conv2D)           (16, 10, 10, 64)          18496
#
#  max_pooling2d_4 (MaxPoolin  (16, 5, 5, 64)            0
#  g2D)
#
#  dropout_4 (Dropout)         (16, 5, 5, 64)            0
#
#  flatten (Flatten)           (16, 1600)                0
#
#  dense (Dense)               (16, 64)                  102464
#
#  dropout_5 (Dropout)         (16, 64)                  0
#
#  dense_1 (Dense)             (16, 4)                   260
#
# =================================================================
# Total params: 178436 (697.02 KB)
# Trainable params: 178436 (697.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'])

# %%
# %%time

history = model.fit(train_set,
                    validation_data = val_set,
                    batch_size = BATCH_SIZE,
                    epochs = 30,
                    verbose = 1
                    )
# Out:
# Epoch 1/20
# 303/303 [==============================] - 440s 1s/step - loss: 1.1204 - accuracy: 0.4835 - val_loss: 0.8875 - val_accuracy: 0.6817
# Epoch 2/20
# 303/303 [==============================] - 431s 1s/step - loss: 0.9188 - accuracy: 0.6203 - val_loss: 0.8967 - val_accuracy: 0.6412
# Epoch 3/20
# 303/303 [==============================] - 418s 1s/step - loss: 0.8317 - accuracy: 0.6660 - val_loss: 0.9925 - val_accuracy: 0.5405
# Epoch 4/20
# 303/303 [==============================] - 426s 1s/step - loss: 0.7816 - accuracy: 0.6953 - val_loss: 0.7592 - val_accuracy: 0.6887
# Epoch 5/20
# 303/303 [==============================] - 421s 1s/step - loss: 0.7312 - accuracy: 0.7116 - val_loss: 0.7900 - val_accuracy: 0.6701
# Epoch 6/20
# 303/303 [==============================] - 420s 1s/step - loss: 0.6851 - accuracy: 0.7351 - val_loss: 0.6762 - val_accuracy: 0.7477
# Epoch 7/20
# 303/303 [==============================] - 419s 1s/step - loss: 0.6320 - accuracy: 0.7531 - val_loss: 0.5736 - val_accuracy: 0.7743
# Epoch 8/20
# 303/303 [==============================] - 420s 1s/step - loss: 0.5846 - accuracy: 0.7700 - val_loss: 0.5590 - val_accuracy: 0.7836
# Epoch 9/20
# 303/303 [==============================] - 421s 1s/step - loss: 0.5610 - accuracy: 0.7900 - val_loss: 0.5769 - val_accuracy: 0.7546
# Epoch 10/20
# 303/303 [==============================] - 421s 1s/step - loss: 0.5427 - accuracy: 0.7902 - val_loss: 0.5795 - val_accuracy: 0.7720
# Epoch 11/20
# 303/303 [==============================] - 426s 1s/step - loss: 0.5097 - accuracy: 0.7923 - val_loss: 0.4703 - val_accuracy: 0.8299
# Epoch 12/20
# 303/303 [==============================] - 419s 1s/step - loss: 0.4932 - accuracy: 0.8080 - val_loss: 0.4078 - val_accuracy: 0.8507
# Epoch 13/20
# 303/303 [==============================] - 421s 1s/step - loss: 0.4522 - accuracy: 0.8261 - val_loss: 0.4164 - val_accuracy: 0.8403
# Epoch 14/20
# 303/303 [==============================] - 420s 1s/step - loss: 0.4475 - accuracy: 0.8333 - val_loss: 0.3630 - val_accuracy: 0.8600
# Epoch 15/20
# 303/303 [==============================] - 419s 1s/step - loss: 0.4318 - accuracy: 0.8426 - val_loss: 0.2918 - val_accuracy: 0.8924
# Epoch 16/20
# 303/303 [==============================] - 419s 1s/step - loss: 0.4058 - accuracy: 0.8533 - val_loss: 0.4206 - val_accuracy: 0.8461
# Epoch 17/20
# 303/303 [==============================] - 423s 1s/step - loss: 0.3921 - accuracy: 0.8550 - val_loss: 0.3346 - val_accuracy: 0.8704
# Epoch 18/20
# 303/303 [==============================] - 420s 1s/step - loss: 0.3583 - accuracy: 0.8659 - val_loss: 0.3258 - val_accuracy: 0.8831
# Epoch 19/20
# 303/303 [==============================] - 424s 1s/step - loss: 0.3611 - accuracy: 0.8665 - val_loss: 0.2699 - val_accuracy: 0.8993
# Epoch 20/20
# 303/303 [==============================] - 419s 1s/step - loss: 0.3435 - accuracy: 0.8725 - val_loss: 0.2842 - val_accuracy: 0.9086

# %%
loss = model.evaluate(test_set)
loss
# Out:
# 82/82 [==============================] - 35s 399ms/step - loss: 0.3953 - accuracy: 0.8635
# [0.39531925320625305, 0.8634629845619202]

# %%
history = history.history

# %%
acc = history['accuracy']
val_acc = history['val_accuracy']

loss = history['loss']
val_loss = history['val_loss']

# %%
plt.plot(acc, label = "Training Accuracy")
plt.plot(val_acc, label = "Validation Accuracy")
plt.legend(loc = 'lower right')
plt.title("Training and Validation accuracy")
plt.show()

# %%
plt.plot(loss, label = "Training loss")
plt.plot(val_loss, label = "Validation loss")
plt.legend(loc = 'upper right')
plt.title("Training and Validation Loss")
plt.show()

# %%
model_version = 1
model.save(f"../outputs/{model_version}")

# make changes to model architecture and save it by changing the model version number
# Out:
# INFO:tensorflow:Assets written to: ../outputs/1\assets
# INFO:tensorflow:Assets written to: ../outputs/1\assets

# %%
model = tf.keras.models.load_model("../outputs/1")

# %%
for images_batch, labels_batch in test_set.take(1):
    displayed_image = images_batch[0].numpy().astype("uint8")
    image_label = labels_batch[0].numpy()
    
    print("Predicting on sample from test set...")
    plt.imshow(displayed_image)
    plt.axis("off")
    image_prediction = model.predict(images_batch)
    actual = class_names[np.argmax(image_prediction[0])]
    predicted = class_names[image_label]
    print("Predicted label: ", actual)
    print("Actual label:", predicted)

# %%
correct = 0
count = 0
incorrect = 0
length = 80
shuffle_set = test_set.shuffle(buffer_size = 1511)

for images_batch, labels_batch in shuffle_set.take(length):
    displayed_image = images_batch[0].numpy().astype("uint8")
    image_label = labels_batch[0].numpy()
    
    image_prediction = model.predict(images_batch)
    actual = class_names[np.argmax(image_prediction[0])]
    predicted = class_names[image_label]
    print("Predicted label: ", actual)
    print("Actual label:", predicted)
    if actual == predicted:
            correct += 1
            print("correct")
            count += 1
    else:
            incorrect += 1
            count += 1
# Out:
# 1/1 [==============================] - 1s 558ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 1s 516ms/step
# Predicted label:  glioma
# Actual label: glioma
# correct
# 1/1 [==============================] - 1s 509ms/step
# Predicted label:  pituitary
# Actual label: pituitary
# correct
# 1/1 [==============================] - 0s 445ms/step
# Predicted label:  glioma
# Actual label: meningioma
# 1/1 [==============================] - 0s 478ms/step
# Predicted label:  notumor
# Actual label: meningioma
# 1/1 [==============================] - 0s 415ms/step
# Predicted label:  pituitary
# Actual label: meningioma
# 1/1 [==============================] - 0s 425ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 0s 427ms/step
# Predicted label:  pituitary
# Actual label: pituitary
# correct
# 1/1 [==============================] - 1s 590ms/step
# Predicted label:  meningioma
# Actual label: meningioma
# correct
# 1/1 [==============================] - 0s 493ms/step
# Predicted label:  glioma
# Actual label: glioma
# correct
# 1/1 [==============================] - 1s 537ms/step
# Predicted label:  pituitary
# Actual label: pituitary
# correct
# 1/1 [==============================] - 0s 482ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 0s 499ms/step
# Predicted label:  pituitary
# Actual label: pituitary
# correct
# 1/1 [==============================] - 0s 465ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 0s 400ms/step
# Predicted label:  meningioma
# Actual label: meningioma
# correct
# 1/1 [==============================] - 0s 459ms/step
# Predicted label:  glioma
# Actual label: glioma
# correct
# 1/1 [==============================] - 0s 409ms/step
# Predicted label:  glioma
# Actual label: glioma
# correct
# 1/1 [==============================] - 0s 396ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 0s 401ms/step
# Predicted label:  pituitary
# Actual label: pituitary
# correct
# 1/1 [==============================] - 0s 496ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 0s 434ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 1s 566ms/step
# Predicted label:  meningioma
# Actual label: meningioma
# correct
# 1/1 [==============================] - 1s 513ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 1s 547ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 1s 565ms/step
# Predicted label:  meningioma
# Actual label: meningioma
# correct
# 1/1 [==============================] - 1s 519ms/step
# Predicted label:  glioma
# Actual label: glioma
# correct
# 1/1 [==============================] - 0s 473ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 0s 466ms/step
# Predicted label:  pituitary
# Actual label: pituitary
# correct
# 1/1 [==============================] - 0s 464ms/step
# Predicted label:  pituitary
# Actual label: pituitary
# correct
# 1/1 [==============================] - 0s 436ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 0s 424ms/step
# Predicted label:  meningioma
# Actual label: meningioma
# correct
# 1/1 [==============================] - 0s 385ms/step
# Predicted label:  meningioma
# Actual label: meningioma
# correct
# 1/1 [==============================] - 0s 409ms/step
# Predicted label:  meningioma
# Actual label: meningioma
# correct
# 1/1 [==============================] - 0s 465ms/step
# Predicted label:  meningioma
# Actual label: meningioma
# correct
# 1/1 [==============================] - 0s 416ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 1s 582ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 0s 444ms/step
# Predicted label:  pituitary
# Actual label: pituitary
# correct
# 1/1 [==============================] - 1s 514ms/step
# Predicted label:  glioma
# Actual label: glioma
# correct
# 1/1 [==============================] - 0s 399ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 0s 428ms/step
# Predicted label:  meningioma
# Actual label: meningioma
# correct
# 1/1 [==============================] - 1s 512ms/step
# Predicted label:  glioma
# Actual label: glioma
# correct
# 1/1 [==============================] - 0s 466ms/step
# Predicted label:  meningioma
# Actual label: glioma
# 1/1 [==============================] - 0s 467ms/step
# Predicted label:  meningioma
# Actual label: meningioma
# correct
# 1/1 [==============================] - 1s 558ms/step
# Predicted label:  meningioma
# Actual label: meningioma
# correct
# 1/1 [==============================] - 1s 533ms/step
# Predicted label:  pituitary
# Actual label: pituitary
# correct
# 1/1 [==============================] - 1s 607ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 1s 512ms/step
# Predicted label:  meningioma
# Actual label: meningioma
# correct
# 1/1 [==============================] - 0s 500ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 1s 560ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 1s 644ms/step
# Predicted label:  glioma
# Actual label: glioma
# correct
# 1/1 [==============================] - 1s 611ms/step
# Predicted label:  pituitary
# Actual label: pituitary
# correct
# 1/1 [==============================] - 0s 490ms/step
# Predicted label:  glioma
# Actual label: glioma
# correct
# 1/1 [==============================] - 1s 524ms/step
# Predicted label:  pituitary
# Actual label: pituitary
# correct
# 1/1 [==============================] - 1s 516ms/step
# Predicted label:  glioma
# Actual label: glioma
# correct
# 1/1 [==============================] - 0s 416ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 0s 443ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 0s 424ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 0s 428ms/step
# Predicted label:  meningioma
# Actual label: meningioma
# correct
# 1/1 [==============================] - 1s 600ms/step
# Predicted label:  glioma
# Actual label: glioma
# correct
# 1/1 [==============================] - 1s 609ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 0s 473ms/step
# Predicted label:  pituitary
# Actual label: pituitary
# correct
# 1/1 [==============================] - 0s 458ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 1s 564ms/step
# Predicted label:  pituitary
# Actual label: pituitary
# correct
# 1/1 [==============================] - 1s 526ms/step
# Predicted label:  glioma
# Actual label: glioma
# correct
# 1/1 [==============================] - 2s 2s/step
# Predicted label:  pituitary
# Actual label: pituitary
# correct
# 1/1 [==============================] - 1s 616ms/step
# Predicted label:  meningioma
# Actual label: meningioma
# correct
# 1/1 [==============================] - 0s 434ms/step
# Predicted label:  meningioma
# Actual label: meningioma
# correct
# 1/1 [==============================] - 0s 449ms/step
# Predicted label:  glioma
# Actual label: glioma
# correct
# 1/1 [==============================] - 0s 484ms/step
# Predicted label:  pituitary
# Actual label: meningioma
# 1/1 [==============================] - 0s 418ms/step
# Predicted label:  notumor
# Actual label: meningioma
# 1/1 [==============================] - 0s 487ms/step
# Predicted label:  glioma
# Actual label: glioma
# correct
# 1/1 [==============================] - 1s 517ms/step
# Predicted label:  pituitary
# Actual label: pituitary
# correct
# 1/1 [==============================] - 1s 517ms/step
# Predicted label:  glioma
# Actual label: glioma
# correct
# 1/1 [==============================] - 1s 565ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 0s 423ms/step
# Predicted label:  pituitary
# Actual label: pituitary
# correct
# 1/1 [==============================] - 0s 429ms/step
# Predicted label:  notumor
# Actual label: meningioma
# 1/1 [==============================] - 0s 449ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct
# 1/1 [==============================] - 0s 383ms/step
# Predicted label:  glioma
# Actual label: glioma
# correct
# 1/1 [==============================] - 0s 383ms/step
# Predicted label:  meningioma
# Actual label: glioma
# 1/1 [==============================] - 0s 386ms/step
# Predicted label:  notumor
# Actual label: notumor
# correct

# %%
count
# Out:
# 80

# %%
correct
# Out:
# 72

# %%
accuracy = int((correct / count) * 100)
print(accuracy,"%")
# Out:
# 90 %

# %%
def predict(model, img):
    image_array = keras.preprocessing.image.img_to_array(images[1].numpy())
    image_array = tf.expand_dims(image_array, 0)
    
    predictions = model.predict(image_array)
    
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(14, 13))
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(images[i])
    plt.title(f"Actual:{class_labels[images[i]]}\nPredicted:{class_labels[label[i]]}")
    plt.axis("off")
    
    
    
plt.figure(figsize=(16,20))
for i in range(0,20):
    plt.subplot(5,4,i+1)
    plt.imshow(x_test[i])
    plt.title(f"Actual:{class_labels[y_test[i]]}\nPredicted:{class_labels[y_pred_test_label[i]]}")
    plt.axis("off")
    
# Correct this for my data but my dataset isnt split into xtrain, xtest, ytrain, ytest, its just images and labels

# %%
plt.figure(figsize = (14, 13))
for images, labels in test_set.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]
        
        #plt.title("Actual class: {}, \n Predicted class: {}, \n Confidence: {}%", actual_class, predicted_class, confidence)
        plt.title(f"Actual: {actual_class}, \n Predicted: {predicted_class}, \n Confidence: {confidence}%")
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 105ms/step

# %%
# this line saves the model just by running, uncomment when new model version is to be saved
#model_version = max([int(i) for i in os.listdir("../saved_models") + [0]]) + 1
#model.save(f"../outputs/{model_version}")

# %%
#model = tf.keras.models.load_model("../outputs/1")
